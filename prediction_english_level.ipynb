# %% [markdown]
# # Lecture des données

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('train_cap2018.csv')

# %%
print(dataset.shape)
# Out:
# (27310, 60)

# %%
dataset
# Out:
#                                                 fulltext  sentences  words  \
# 0      \r\r\n      The Eiffel Tower The Eiffel Tower ...         16    233
# 1      \r\r\n      The Court Green burglar arrested A...          7    180
# 2      \r\r\n      Thank you for giving us the opport...         10    180
# 3      \r\r\n      The international AI conference ca...         10    180
# 4      \r\r\n      I believe that the creative writin...         11    187
# 5      \r\r\n      Robots help perform more than 300,...          9    180
# 6      \r\r\n      The three robots mentionned in the...          5    130
# 7      \r\r\n      The Place de la Comdie in Montpell...          9    183
# 8      \r\r\n      Route ##, Main Street of America.....         11    185
# 9      \r\r\n      Human can think and have a soul. R...          9    157
# 10     \r\r\n      I would like to speak about my Pre...          5    104
# 11     \r\r\n      Lyon, a beautiful city of France l...         21    377
# 12     \r\r\n      Have your ever heard about the leg...          9    191
# 13     The Eiffel Tower is the symbol of France and o...          8    155
# 14     \r\r\n      Iam in Balis Island. So peaceful, ...         13    173
# 15     \r\r\n      I am very impressed by the purpose...          4    121
# 16     \r\r\n      Thanks to the technological progre...         10    151
# 17     \r\r\n      I don't want to be this gossip boy...         10    180
# 18     \r\r\n      These three robots are a great exa...          9    150
# 19     \r\r\n      Good evening, Robots are used in t...         10    167
# 20     \r\r\n      Title : The Imperial Cities All th...          7    148
# 21     \r\r\n      In France , robots are commonly us...          6     80
# 22     \r\r\n      How can robots help mankind ? The ...         12    182
# 23     \r\r\n      I don't want to be this gossip boy...         10    207
# 24     \r\r\n      Dear Banker,My name is Rosa R Benn...          7    174
# 25     \r\r\n      Well, now me and my wife can say t...          8    171
# 26     \r\r\n      Each person has his own way of wri...         11    162
# 27     \r\r\n      Three types of service robots that...          9    153
# 28     \r\r\n      Well, again I will discuss trough ...         10    213
# 29     \r\r\n      My name is Omar, I am a great repo...         12    177
# ...                                                  ...        ...    ...
# 27280  \r\r\n      a light pink jacket is 5,99$ a dar...          2     21
# 27281  \r\r\n      Can you buy me. Fish A bottle of j...          3     42
# 27282  \r\r\n      Hi, my name's Fabio. Nice to meet ...          5     14
# 27283  \r\r\n      I live in a small and beautiful to...          7     38
# 27284  \r\r\n      Good morning,My name's Larissa Bou...          3     45
# 27285  \r\r\n      I like go at to a mall.There are a...          6     39
# 27286  \r\r\n      I'm so sorry about the weather, bu...          6     41
# 27287  \r\r\n      Hi!My name's Stephanie.I'm thirty ...          3     28
# 27288  \r\r\n      Hello Jim I order clothes online. ...          6     54
# 27289  \r\r\n      I enjoy practice soccer on a team....          8     29
# 27290  \r\r\n      My name is Pradel. I'm PhD of chem...          4     54
# 27291  \r\r\n      Je m'appelle Victoire, je suis ge ...          1     27
# 27292  \r\r\n      Hi Ed ! She likes books, flowers a...          3     24
# 27293  \r\r\n      Hi ! My name's Mireille.I'm sixty ...          5     55
# 27294  \r\r\n      In my office, there are a lot of c...          3     40
# 27295  \r\r\n      Name: Raph Duffy Age: 35 Eyes colo...          2     32
# 27296  \r\r\n      Date: Monday 11thTime: 9.30amFrom:...          6     40
# 27297  \r\r\n      The online catalog has: - white sn...          1     25
# 27298  \r\r\n      hi, my name's Fanny. i want  speak...          8    100
# 27299  \r\r\n      In my country, everything is going...          9     37
# 27300  \r\r\n      I'm from Paris. Paris is a big cit...          8    108
# 27301  \r\r\n      hi, my name's melanie. I'm twenty ...          4     24
# 27302  \r\r\n      in the office, there are a lot of ...          8     39
# 27303  \r\r\n      April,3th Dear Friends, Company's ...          5     68
# 27304  \r\r\n      sixteen headphones. also there are...          3     14
# 27305  \r\r\n      Hi my name's Jean-Marc. I'm a mana...          8     76
# 27306  \r\r\n      - the exercise start tomorrow - na...          2     27
# 27307  \r\r\n      Good evening. How are you? I'm fin...          2     20
# 27308  \r\r\n      The festival Beauregard lasts thre...          5     27
# 27309  \r\r\n      Hi Andrea! My name's Cindy. I'm fr...          1     38
#
#        letters.all  syllables  punct  avg.sentc.length  avg.word.length  \
# 0             1116        363     32         14.562500         4.789700
# 1              866        268     18         25.714286         4.811111
# 2              861        269     20         18.000000         4.783333
# 3              872        281     20         18.000000         4.844444
# 4              849        283     29         17.000000         4.540107
# 5              857        272     24         20.000000         4.761111
# 6              607        197     15         26.000000         4.669231
# 7              717        229     24         20.333333         3.918033
# 8              788        251     42         16.818182         4.259459
# 9              641        208     20         17.444444         4.082803
# 10             440        148     12         20.800000         4.230769
# 11            1698        562     41         17.952381         4.503979
# 12             797        265     23         21.222222         4.172775
# 13             732        248     13         19.375000         4.722581
# 14             734        237     22         13.307692         4.242775
# 15             519        166     13         30.250000         4.289256
# 16             724        249     16         15.100000         4.794702
# 17             754        248     30         18.000000         4.188889
# 18             658        230     10         16.666667         4.386667
# 19             774        252     24         16.700000         4.634731
# 20             719        234     10         21.142857         4.858108
# 21             341        111     14         13.333333         4.262500
# 22             921        297     21         15.166667         5.060440
# 23             860        288     30         20.700000         4.154589
# 24             748        238     25         24.857143         4.298851
# 25             667        213     19         21.375000         3.900585
# 26             712        230     24         14.727273         4.395062
# 27             742        231     16         17.000000         4.849673
# 28             906        307     32         21.300000         4.253521
# 29             874        304     21         14.750000         4.937853
# ...            ...        ...    ...               ...              ...
# 27280           77         24      3         10.500000         3.666667
# 27281          145         54     11         14.000000         3.452381
# 27282           49         15      7          2.800000         3.500000
# 27283          126         45     13          5.428571         3.315789
# 27284          168         57      6         15.000000         3.733333
# 27285          167         52      9          6.500000         4.282051
# 27286          169         53      7          6.833333         4.121951
# 27287          142         38      4          9.333333         5.071429
# 27288          237         88      9          9.000000         4.388889
# 27289           92         39     12          3.625000         3.172414
# 27290          193         66      9         13.500000         3.574074
# 27291          101         32      5         27.000000         3.740741
# 27292           96         28      4          8.000000         4.000000
# 27293          230         78      8         11.000000         4.181818
# 27294          150         49      6         13.333333         3.750000
# 27295          137         38      6         16.000000         4.281250
# 27296          128         44     11          6.666667         3.200000
# 27297          115         37      5         25.000000         4.600000
# 27298          410        133     13         12.500000         4.100000
# 27299          148         44     13          4.111111         4.000000
# 27300          447        150     19         13.500000         4.138889
# 27301           80         27      8          6.000000         3.333333
# 27302          138         49     17          4.875000         3.538462
# 27303          256         81     11         13.600000         3.764706
# 27304           63         20      6          4.666667         4.500000
# 27305          339        118     15          9.500000         4.460526
# 27306          115         34      5         13.500000         4.259259
# 27307           63         23      4         10.000000         3.150000
# 27308          107         37      8          5.400000         3.962963
# 27309          174         52      7         38.000000         4.578947
#
#        avg.syll.word  sntc.per.word   ...    Maas lgV0  MATTR  MSTTR    MTLD  \
# 0           1.557940       0.068670   ...         4.96   0.72   0.70   70.74
# 1           1.488889       0.038889   ...         5.07   0.74   0.76  107.12
# 2           1.494444       0.055556   ...         5.99   0.77   0.78  161.93
# 3           1.561111       0.055556   ...         5.49   0.77   0.81  141.10
# 4           1.513369       0.058824   ...         4.61   0.68   0.64   70.69
# 5           1.511111       0.050000   ...         5.13   0.71   0.73  100.72
# 6           1.515385       0.038462   ...         5.04   0.73   0.73   88.86
# 7           1.251366       0.049180   ...         3.99   0.62   0.60   41.25
# 8           1.356757       0.059459   ...         5.52   0.73   0.78  111.92
# 9           1.324841       0.057325   ...         4.50   0.66   0.63   53.33
# 10          1.423077       0.048077   ...         5.74   0.78   0.77   79.10
# 11          1.490716       0.055703   ...         4.91   0.70   0.67   78.70
# 12          1.387435       0.047120   ...         5.27   0.75   0.72   99.84
# 13          1.600000       0.051613   ...         3.93   0.61   0.57   38.88
# 14          1.369942       0.075145   ...         5.41   0.70   0.71   98.02
# 15          1.371901       0.033058   ...         4.77   0.71   0.68   69.57
# 16          1.649007       0.066225   ...         4.59   0.68   0.67   60.40
# 17          1.377778       0.055556   ...         5.31   0.74   0.78  108.83
# 18          1.533333       0.060000   ...         4.22   0.62   0.66   64.92
# 19          1.508982       0.059880   ...         5.43   0.74   0.72   91.80
# 20          1.581081       0.047297   ...         4.44   0.65   0.65   54.32
# 21          1.387500       0.075000   ...         5.96    NaN    NaN  119.47
# 22          1.631868       0.065934   ...         5.69   0.78   0.84  126.80
# 23          1.391304       0.048309   ...         5.03   0.74   0.74   85.86
# 24          1.367816       0.040230   ...         5.01   0.68   0.73   78.48
# 25          1.245614       0.046784   ...         4.35   0.64   0.66   58.46
# 26          1.419753       0.067901   ...         4.88   0.72   0.71   81.74
# 27          1.509804       0.058824   ...         4.54   0.71   0.71   78.37
# 28          1.441315       0.046948   ...         5.14   0.72   0.74   99.98
# 29          1.717514       0.067797   ...         5.04   0.72   0.75   84.48
# ...              ...            ...   ...          ...    ...    ...     ...
# 27280       1.142857       0.095238   ...         2.57    NaN    NaN   21.00
# 27281       1.285714       0.071429   ...         3.56    NaN    NaN   30.07
# 27282       1.071429       0.357143   ...         4.73    NaN    NaN   54.88
# 27283       1.184211       0.184211   ...         4.17    NaN    NaN   50.54
# 27284       1.266667       0.066667   ...         3.46    NaN    NaN   45.00
# 27285       1.333333       0.153846   ...         4.28    NaN    NaN   53.23
# 27286       1.292683       0.146341   ...         4.89    NaN    NaN   67.24
# 27287       1.357143       0.107143   ...         4.02    NaN    NaN   43.90
# 27288       1.629630       0.111111   ...         5.20    NaN    NaN   81.65
# 27289       1.344828       0.275862   ...         2.64    NaN    NaN   19.33
# 27290       1.222222       0.074074   ...         3.69    NaN    NaN   35.88
# 27291       1.185185       0.037037   ...         2.61    NaN    NaN   21.51
# 27292       1.166667       0.125000   ...         3.40    NaN    NaN   32.26
# 27293       1.418182       0.090909   ...         4.10    NaN    NaN   55.72
# 27294       1.225000       0.075000   ...         4.76    NaN    NaN   64.00
# 27295       1.187500       0.062500   ...         3.77    NaN    NaN   40.96
# 27296       1.100000       0.150000   ...         3.19    NaN    NaN   19.92
# 27297       1.480000       0.040000   ...         3.56    NaN    NaN   35.00
# 27298       1.330000       0.080000   ...         4.89    NaN   0.71   86.56
# 27299       1.189189       0.243243   ...         2.91    NaN    NaN   23.32
# 27300       1.388889       0.074074   ...         4.15   0.63   0.65   60.15
# 27301       1.125000       0.166667   ...         3.02    NaN    NaN   26.88
# 27302       1.256410       0.205128   ...         3.48    NaN    NaN   30.06
# 27303       1.191176       0.073529   ...         3.72    NaN    NaN   57.70
# 27304       1.428571       0.214286   ...         4.73    NaN    NaN   54.88
# 27305       1.552632       0.105263   ...         4.19    NaN    NaN   56.71
# 27306       1.259259       0.074074   ...         5.21    NaN    NaN   68.04
# 27307       1.150000       0.100000   ...         4.78    NaN    NaN   56.00
# 27308       1.370370       0.185185   ...         4.42    NaN    NaN   51.03
# 27309       1.368421       0.026316   ...         3.38    NaN    NaN   21.14
#
#        Root TTR  Summer  TTR.1  Uber index  Yule's K  level1
# 0          8.98    0.88   0.59       24.30    146.62      C2
# 1          8.57    0.89   0.64       26.14    141.98      C2
# 2          9.62    0.92   0.72       35.15     62.96      C2
# 3          9.09    0.90   0.68       30.11     70.99      C2
# 4          7.97    0.87   0.58       22.02    124.11      C2
# 5          8.65    0.89   0.64       26.66     91.98      C2
# 6          7.81    0.89   0.68       27.16    111.24      C2
# 7          6.87    0.83   0.51       17.41    195.29      C2
# 8          9.19    0.90   0.68       30.19    138.50      C2
# 9          7.50    0.86   0.60       21.65    129.01      C2
# 10         7.84    0.92   0.77       35.71     77.66      C2
# 11         9.84    0.87   0.51       22.48    133.40      C2
# 12         8.97    0.90   0.65       27.73    114.58      C2
# 13         6.59    0.83   0.53       17.35    322.16      C2
# 14         8.90    0.90   0.68       29.49     94.89      C2
# 15         7.36    0.88   0.67       24.89    101.09      C2
# 16         7.57    0.87   0.62       22.56    118.42      C2
# 17         8.87    0.90   0.66       28.30     80.86      C2
# 18         7.02    0.85   0.57       19.60    170.67      C2
# 19         8.82    0.90   0.68       29.80    149.16      C2
# 20         7.32    0.86   0.60       21.32    209.09      C2
# 21         7.27    0.92   0.81       40.16     62.50      C2
# 22         9.34    0.91   0.69       31.98     76.68      C2
# 23         8.83    0.89   0.61       25.28     87.28      C2
# 24         8.41    0.89   0.64       25.71    154.58      C2
# 25         7.42    0.85   0.57       20.25    142.95      C2
# 26         8.09    0.88   0.64       24.82    103.64      C2
# 27         7.52    0.87   0.61       22.08    111.92      C2
# 28         9.04    0.89   0.62       26.09     96.98      C2
# 29         8.49    0.89   0.64       25.93     94.48      C2
# ...         ...     ...    ...         ...       ...     ...
# 27280      3.27    0.58   0.71       11.96    317.46      A1
# 27281      4.63    0.81   0.71       18.03    351.47      A1
# 27282      3.47    0.79   0.93       40.81    102.04      A1
# 27283      4.87    0.85   0.79       24.31    152.35      A1
# 27284      4.62    0.80   0.69       16.89    187.65      A1
# 27285      4.96    0.86   0.79       25.39    131.49      A1
# 27286      5.31    0.89   0.83       31.99    107.08      A1
# 27287      4.35    0.84   0.82       24.51    178.57      A1
# 27288      5.99    0.90   0.81       33.74    137.17      A1
# 27289      3.53    0.65   0.66       11.65    499.41      A1
# 27290      5.04    0.82   0.69       18.28    322.36      A1
# 27291      3.46    0.63   0.67       11.63    493.83      A1
# 27292      3.88    0.76   0.79       18.78    173.61      A1
# 27293      5.39    0.85   0.73       21.90    132.23      A1
# 27294      5.22    0.89   0.82       30.72    100.00      A1
# 27295      4.42    0.82   0.78       21.13    253.91      A1
# 27296      4.27    0.76   0.68       15.04    375.00      A1
# 27297      4.00    0.79   0.80       20.17    256.00      A1
# 27298      7.10    0.89   0.71       26.89     88.00      A1
# 27299      3.95    0.72   0.65       13.08    262.97      A1
# 27300      6.45    0.85   0.62       19.94    121.74      A1
# 27301      3.67    0.71   0.75       15.25    416.67      A1
# 27302      4.48    0.80   0.72       17.59    276.13      A1
# 27303      5.34    0.82   0.65       17.76    177.34      A1
# 27304      3.47    0.79   0.93       40.81    102.04      A1
# 27305      5.96    0.85   0.68       21.46    211.22      A1
# 27306      4.62    0.90   0.89       40.05    109.74      A1
# 27307      4.02    0.86   0.90       36.99    100.00      A1
# 27308      4.43    0.86   0.85       29.42    137.17      A1
# 27309      4.38    0.78   0.71       16.82    221.61      A1
#
# [27310 rows x 60 columns]

# %%
print(dataset.loc[0, 'fulltext'])
# Out:
#       The Eiffel Tower The Eiffel Tower is a symbol of domination of man over steel. It also symbolizes the great maturity of architecture. Its message resonates not only in France but throughout the whole world. With opportunity of the Universal Exhibition which celebrates the 1789 century revolution, the resurgent republic wanted to make a great shot. It launched a contest in the Official Journal engineers putting the challenge to raise 'in the Champ-de-Mars an iron tower with a square base, 125 meters wide and 300 meters high.&quot; The project was won and built by Gustave Eiffel for the Universal Exhibition of 1889. Everyone has once dreamed visiting Paris and is really amazing tower. Situated in the 15th Paris district, it is now the most visited paid monument in the world, with 6,893,000 visitors in 2007. We invite you to discover some of the secrets of the &quot;Iron Lady&quot;. Its an international place where you can meet the whole world. Its absolutely wonderful to see how French people are open-minded, how they like welcoming tourists visiting their country, how they are proud to share with other people a part of their living style. You can visit and go to restaurant in the same place. You can also discover the French history and buy memories on French history over centuries. To me the tower not symbolize our past but the footprint of French greatness.

# %% [markdown]
# # Ensembles d'entrainement et de test

# %%
from sklearn.model_selection import train_test_split
test_size = 0.2
random_state = 42

# %%
train, test = train_test_split(dataset, test_size=test_size, random_state=random_state, shuffle=True, stratify=dataset.loc[:,'level1'])
print(train.shape)
print(test.shape)
# Out:
# (21848, 60)
# (5462, 60)

# %%
X_train = train.iloc[:, :-1]
y_train = train.iloc[:, -1]
print(X_train.shape)
print(y_train.shape)
# Out:
# (21848, 59)
# (21848,)

# %% [markdown]
# # Analyse de l'ensemble d'entrainement

# %%
X_train
# Out:
#                                                 fulltext  sentences  words  \
# 17424  \r\r\n      Hello, Why don't you buy the orang...          6     35
# 18934  \r\r\n      Good evening, how are you ? I'm fi...          6     52
# 4305   \r\r\n      CAREER PLAN Name : Jean-Philippe B...          5     72
# 13039  \r\r\n      Hi My favortite hobby with my fami...          2     73
# 13124  \r\r\n      My great job, but... I am a manage...          4     55
# 975    \r\r\n      Here is the story of a friend of m...          7    156
# 15651  \r\r\n      I Love to travel. I've visited Tha...         11     78
# 7858   \r\r\n      While I was studying the Law, I ha...         13    104
# 16417  \r\r\n      Hello, My name's Erwan. I'm in gre...          5     24
# 9218   \r\r\n      John learn that Isabella should to...          8     73
# 5558   \r\r\n      To whom it may concern: I am writi...          5    121
# 6960   \r\r\n      Hello,I'm really sorry to tell you...          8    130
# 26357  \r\r\n      My name's Dominique, I am buyer, I...          3     25
# 8452   \r\r\n      Today at 6.30 p.m I'm going to a l...          1     15
# 17726  \r\r\n      HI,sorry the weather is horrible a...          5     38
# 6621   \r\r\n      For some aches, home remedies coul...         12    103
# 13599  \r\r\n      HelloFor my birthday I'd like to d...          3     53
# 21122  \r\r\n      Dear Sir or Madam, My name is Adel...          8     37
# 22536  \r\r\n      Hi. The online catalog has : -snea...          7     47
# 7917   \r\r\n      Dear Mom and Dad, In September, I ...          7    118
# 10313  \r\r\n      In Santa Monica today it's going t...         14    101
# 1400   \r\r\n      I think the president board prepar...         18    130
# 12854  \r\r\n      Hi Mom and Dad,Today we are in San...          3     80
# 16046  \r\r\n      Date : Monday 11th Time : 9.30 am ...          7     37
# 15536  \r\r\n      I work in an office. I sit an my d...          5     72
# 16577  \r\r\n      Name: Mehdy. Age: eight and half. ...          1     87
# 22664  \r\r\n      My name's Brigitte. I'm 64 years o...          6     32
# 3501   \r\r\n      Dear Mr Gibson,Thanks for your ans...          7    117
# 22119  \r\r\n      Dear Ms Thomas, There are thirty p...          3     28
# 14467  \r\r\n      Hi Mum and Dad,I'm in Santa Monica...          3     59
# ...                                                  ...        ...    ...
# 20948  \r\r\n      Good afternoon ladies and gentleme...          1     40
# 23160  \r\r\n      Nancy is a lively city. It's name,...          4     33
# 294    \r\r\n      The three paintings which will be ...         11    138
# 26546  \r\r\n      Hi, my name's reda , I'm twenty si...          1     29
# 26592  \r\r\n      Hi ! I'm 40 years old on sunday. I...          1     23
# 5921   \r\r\n      First, I suppose to finish my mast...          5     77
# 10436  \r\r\n      Hello everybody!Thurday 6th May at...          9     82
# 15126  \r\r\n      This year, I'm going to a music fe...          8     50
# 26936  \r\r\n      Tom Parker head of marketing form ...          3     20
# 26751  \r\r\n      hello,My name's Gilles. I live's i...          5     23
# 23610  \r\r\n      I'm sorry about the weather. You s...          4     41
# 7174   \r\r\n      Mark a bowling area of 8 by 3 mete...          9    100
# 26668  \r\r\n      Dear Ms Thomas, There are 30 pens,...          5     30
# 7282   \r\r\n      I have listened the song wich is c...          5     63
# 12623  \r\r\n      Hi!I like surfing in the Manche be...          1     69
# 18890  \r\r\n      Hi! My name is Abdel. I'm forty-si...          3     36
# 14348  \r\r\n      There was a murder in my country l...          5     54
# 7897   \r\r\n      Hi or maybe once. Anyway I hope I ...          5    102
# 19331  \r\r\n      I ususally shop in small shops. I ...          7     27
# 23062  \r\r\n      hi my name is Patricia Erbetta,i'm...          3     13
# 8159   \r\r\n      Today I just got my degree for the...          6    109
# 10461  \r\r\n      I am a manager and an architect. I...         14     85
# 22960  \r\r\n      Good evening. How are you? I'm fin...          3     37
# 20251  \r\r\n      Hi!This is Pete's the menu.Baked c...          4     28
# 8129   \r\r\n      Im from France. France is a beauti...          6    107
# 5929   \r\r\n      I am very optimist for the futur. ...          6     62
# 15435  \r\r\n      Dear, I'm looking forward to see y...          6     60
# 1280   \r\r\n      Hi, Anna ! I've found the perfect ...          3     59
# 25741  \r\r\n      I can recommend the Center hotel. ...          5     42
# 14168  \r\r\n      For : ABC Insurance Subject : robb...          8     67
#
#        letters.all  syllables  punct  avg.sentc.length  avg.word.length  \
# 17424          144         48     11          5.833333         4.114286
# 18934          198         70     10          8.666667         3.807692
# 4305           252         82      9         14.400000         3.500000
# 13039          263         90      9         36.500000         3.602740
# 13124          239         79      5         13.750000         4.345455
# 975            684        221     12         22.285714         4.384615
# 15651          347        109     11          7.090909         4.448718
# 7858           391        137     24          8.000000         3.759615
# 16417           76         29      9          4.800000         3.166667
# 9218           294        100     10          9.125000         4.027397
# 5558           440        149     11         24.200000         3.636364
# 6960           521        176     24         16.250000         4.007692
# 26357          110         35      5          8.333333         4.400000
# 8452            64         21      0         15.000000         4.266667
# 17726          159         53     12          7.600000         4.184211
# 6621           392        125     21          8.583333         3.805825
# 13599          233         77     13         17.666667         4.396226
# 21122          146         42     10          4.625000         3.945946
# 22536          199         69     17          6.714286         4.234043
# 7917           484        154     17         16.857143         4.101695
# 10313          466        152     27          7.214286         4.613861
# 1400           671        222     20          7.222222         5.161538
# 12854          312        110     14         26.666667         3.900000
# 16046          137         48     10          5.285714         3.702703
# 15536          287         95     12         14.400000         3.986111
# 16577          345        105     18         87.000000         3.965517
# 22664          152         50      8          5.333333         4.750000
# 3501           437        149     31         16.714286         3.735043
# 22119           94         32      6          9.333333         3.357143
# 14467          255         80      7         19.666667         4.322034
# ...            ...        ...    ...               ...              ...
# 20948          147         48      3         40.000000         3.675000
# 23160          134         41      9          8.250000         4.060606
# 294            676        211     20         12.545455         4.898551
# 26546          124         43      9         29.000000         4.275862
# 26592           95         34      7         23.000000         4.130435
# 5921           309         94      7         15.400000         4.012987
# 10436          355        109     13          9.111111         4.329268
# 15126          241         76     20          6.250000         4.820000
# 26936           58         21      5          6.666667         2.900000
# 26751           77         27      9          4.600000         3.347826
# 23610          149         54      9         10.250000         3.634146
# 7174           438        149     20         11.111111         4.380000
# 26668          110         44     11          6.000000         3.666667
# 7282           295        103     11         12.600000         4.682540
# 12623          277         99     11         69.000000         4.014493
# 18890          132         51     13         12.000000         3.666667
# 14348          202         71      8         10.800000         3.740741
# 7897           462        149     15         20.400000         4.529412
# 19331           92         32      8          3.857143         3.407407
# 23062           49         15      7          4.333333         3.769231
# 8159           420        150     21         18.166667         3.853211
# 10461          336        108     26          6.071429         3.952941
# 22960          141         47      9         12.333333         3.810811
# 20251          134         41      8          7.000000         4.785714
# 8129           469        145     18         17.833333         4.383178
# 5929           242         82     15         10.333333         3.903226
# 15435          247         76     19         10.000000         4.116667
# 1280           240         80      6         19.666667         4.067797
# 25741          154         48     15          8.400000         3.666667
# 14168          262         87     10          8.375000         3.910448
#
#        avg.syll.word  sntc.per.word    ...     Maas a  Maas lgV0  MATTR  \
# 17424       1.371429       0.171429    ...       0.19       4.56    NaN
# 18934       1.346154       0.115385    ...       0.22       4.05    NaN
# 4305        1.138889       0.069444    ...       0.24       3.63    NaN
# 13039       1.232877       0.027397    ...       0.20       4.55    NaN
# 13124       1.436364       0.072727    ...       0.19       4.73    NaN
# 975         1.416667       0.044872    ...       0.20       4.81   0.71
# 15651       1.397436       0.141026    ...       0.21       4.31    NaN
# 7858        1.317308       0.125000    ...       0.20       4.76   0.69
# 16417       1.208333       0.208333    ...       0.23       3.40    NaN
# 9218        1.369863       0.109589    ...       0.21       4.27    NaN
# 5558        1.231405       0.041322    ...       0.21       4.60   0.66
# 6960        1.353846       0.061538    ...       0.20       4.72   0.69
# 26357       1.400000       0.120000    ...       0.25       3.16    NaN
# 8452        1.400000       0.066667    ...       0.21       3.47    NaN
# 17726       1.394737       0.131579    ...       0.24       3.38    NaN
# 6621        1.213592       0.116505    ...       0.20       4.62   0.68
# 13599       1.452830       0.056604    ...       0.15       5.82    NaN
# 21122       1.135135       0.216216    ...       0.28       2.91    NaN
# 22536       1.468085       0.148936    ...       0.19       4.52    NaN
# 7917        1.305085       0.059322    ...       0.20       4.64   0.67
# 10313       1.504950       0.138614    ...       0.20       4.83   0.70
# 1400        1.707692       0.138462    ...       0.22       4.24   0.65
# 12854       1.375000       0.037500    ...       0.18       5.16    NaN
# 16046       1.297297       0.189189    ...       0.12       7.12    NaN
# 15536       1.319444       0.069444    ...       0.19       4.80    NaN
# 16577       1.206897       0.011494    ...       0.22       4.13    NaN
# 22664       1.562500       0.187500    ...       0.25       3.20    NaN
# 3501        1.273504       0.059829    ...       0.20       4.86   0.70
# 22119       1.142857       0.107143    ...       0.22       3.59    NaN
# 14467       1.355932       0.050847    ...       0.19       4.61    NaN
# ...              ...            ...    ...        ...        ...    ...
# 20948       1.200000       0.025000    ...       0.23       3.58    NaN
# 23160       1.242424       0.121212    ...       0.19       4.29    NaN
# 294         1.528986       0.079710    ...       0.20       4.87   0.69
# 26546       1.482759       0.034483    ...       0.17       4.76    NaN
# 26592       1.478261       0.043478    ...       0.15       5.53    NaN
# 5921        1.220779       0.064935    ...       0.20       4.65    NaN
# 10436       1.329268       0.109756    ...       0.19       4.96    NaN
# 15126       1.520000       0.160000    ...       0.16       5.50    NaN
# 26936       1.050000       0.150000    ...       0.11       6.94    NaN
# 26751       1.173913       0.217391    ...       0.15       5.53    NaN
# 23610       1.317073       0.097561    ...       0.23       3.68    NaN
# 7174        1.490000       0.090000    ...       0.17       5.68    NaN
# 26668       1.466667       0.166667    ...       0.21       3.87    NaN
# 7282        1.634921       0.079365    ...       0.20       4.53    NaN
# 12623       1.434783       0.014493    ...       0.22       4.15    NaN
# 18890       1.416667       0.083333    ...       0.26       3.18    NaN
# 14348       1.314815       0.092593    ...       0.19       4.65    NaN
# 7897        1.460784       0.049020    ...       0.21       4.57   0.67
# 19331       1.185185       0.259259    ...       0.16       5.21    NaN
# 23062       1.153846       0.230769    ...       0.17       4.35    NaN
# 8159        1.376147       0.055046    ...       0.24       3.90   0.59
# 10461       1.270588       0.164706    ...       0.21       4.46    NaN
# 22960       1.270270       0.081081    ...       0.28       2.91    NaN
# 20251       1.464286       0.142857    ...       0.26       2.97    NaN
# 8129        1.355140       0.056075    ...       0.20       4.80   0.70
# 5929        1.322581       0.096774    ...       0.20       4.45    NaN
# 15435       1.266667       0.100000    ...       0.28       3.01    NaN
# 1280        1.355932       0.050847    ...       0.19       4.83    NaN
# 25741       1.142857       0.119048    ...       0.19       4.62    NaN
# 14168       1.298507       0.119403    ...       0.23       3.77    NaN
#
#        MSTTR    MTLD  Root TTR  Summer  TTR.1  Uber index  Yule's K
# 17424    NaN   57.17      4.90    0.87   0.83       29.19    146.94
# 18934    NaN   46.51      5.27    0.85   0.73       21.62    244.08
# 4305     NaN   32.97      5.30    0.81   0.62       16.90    300.93
# 13039    NaN   73.79      6.20    0.88   0.73       24.97    105.09
# 13124    NaN   70.58      5.80    0.89   0.78       28.34     99.17
# 975     0.67   81.56      7.93    0.88   0.63       24.35    126.56
# 15651    NaN   55.24      6.11    0.86   0.69       22.42    167.65
# 7858    0.69   60.94      7.06    0.88   0.69       25.48    214.50
# 16417    NaN   32.26      3.88    0.76   0.79       18.78    208.33
# 9218     NaN   54.69      5.97    0.86   0.70       22.29    206.42
# 5558    0.68   60.61      7.18    0.87   0.65       23.43    173.49
# 6960    0.70   68.55      7.45    0.88   0.65       24.22    134.91
# 26357    NaN   26.92      3.80    0.73   0.76       16.40    288.00
# 8452     NaN   31.50      3.36    0.67   0.87       22.26    177.78
# 17726    NaN   31.29      4.38    0.78   0.71       16.82    304.71
# 6621    0.67   70.86      6.90    0.88   0.68       24.15    111.23
# 13599    NaN   98.32      6.18    0.92   0.85       41.84     64.08
# 21122    NaN   24.36      3.95    0.72   0.65       13.08    292.18
# 22536    NaN   61.85      5.40    0.88   0.79       26.91    126.75
# 7917    0.67   76.84      7.18    0.88   0.66       23.88    124.96
# 10313   0.70   84.28      7.06    0.89   0.70       26.25    127.44
# 1400    0.62   57.32      6.84    0.85   0.60       20.14    168.05
# 12854    NaN   94.32      6.82    0.90   0.76       30.76     81.25
# 16046    NaN  127.77      5.59    0.95   0.92       66.97     43.83
# 15536    NaN   80.64      6.36    0.89   0.75       27.61    119.60
# 16577    NaN   51.52      6.11    0.85   0.66       20.48    169.11
# 22664    NaN   27.85      4.07    0.76   0.72       15.80    312.50
# 3501    0.67   57.78      7.40    0.89   0.68       25.91     84.74
# 22119    NaN   31.72      4.16    0.80   0.79       20.00    229.59
# 14467    NaN   69.62      5.86    0.88   0.76       26.66    126.40
# ...      ...     ...       ...     ...    ...         ...       ...
# 20948    NaN   31.60      4.59    0.81   0.72       18.38    200.00
# 23160    NaN   36.11      4.70    0.86   0.82       26.46    146.92
# 294     0.71   76.67      7.75    0.88   0.66       25.32    183.78
# 26546    NaN   58.87      4.64    0.88   0.86       33.18    118.91
# 26592    NaN   74.06      4.38    0.90   0.91       46.93     75.61
# 5921     NaN   55.52      6.38    0.88   0.73       25.73    134.93
# 10436    NaN   89.65      6.74    0.89   0.74       28.51     92.21
# 15126    NaN   87.50      5.94    0.91   0.84       38.12    112.00
# 26936    NaN  112.00      4.25    0.93   0.95       75.99     50.00
# 26751    NaN   74.06      4.38    0.90   0.91       46.93     75.61
# 23610    NaN   41.88      4.69    0.82   0.73       19.17    273.65
# 7174    0.77  121.74      7.70    0.92   0.77       35.24     94.00
# 26668    NaN   42.00      4.38    0.83   0.80       22.51    155.56
# 7282     NaN   69.46      5.92    0.88   0.75       25.44    120.94
# 12623    NaN   56.41      5.78    0.85   0.70       21.45    168.03
# 18890    NaN   36.00      4.17    0.76   0.69       15.29    216.05
# 14348    NaN   44.65      5.72    0.88   0.78       27.50    192.04
# 7897    0.68   51.89      6.83    0.87   0.68       23.77    263.36
# 19331    NaN   68.04      4.62    0.90   0.89       40.05     82.30
# 23062    NaN   47.32      3.33    0.71   0.92       35.70    118.34
# 8159    0.61   56.13      6.13    0.83   0.59       17.95    210.42
# 10461    NaN   73.58      6.40    0.87   0.69       23.48    105.19
# 22960    NaN   30.87      3.95    0.72   0.65       13.08    292.18
# 20251    NaN   28.00      3.78    0.71   0.71       14.33    255.10
# 8129    0.69   78.50      7.15    0.88   0.69       25.72    129.27
# 5929     NaN   51.71      5.84    0.87   0.74       24.78    114.46
# 15435    NaN   31.07      4.39    0.74   0.57       12.82    316.67
# 1280     NaN   74.98      5.99    0.89   0.78       29.01     97.67
# 25741    NaN   49.99      5.25    0.88   0.81       28.71    102.04
# 14168    NaN   32.07      5.38    0.83   0.66       18.26    334.15
#
# [21848 rows x 59 columns]

# %% [markdown]
# ## Données manquantes

# %%
X_train.isnull().values.sum()
# Out:
# 34749

# %% [markdown]
# Deux variables ont toutes les valeurs manquantes:

# %%
X_train.loc[:,'MATTR'].isnull().values.sum() + X_train.loc[:,'MSTTR'].isnull().values.sum()
# Out:
# 34749

# %%
X_train = X_train.drop(['MATTR', 'MSTTR'], axis=1)

# %%
X_train.isnull().values.any()
# Out:
# False

# %% [markdown]
# ## Types de données

# %%
pd.set_option('display.max_columns', 100)
X_train.describe()
# Out:
#           sentences        words   letters.all     syllables         punct  \
# count  21848.000000  21848.00000  21848.000000  21848.000000  21848.000000
# mean       6.180428     69.65585    287.098636     95.009795     13.454367
# std        3.560878     41.70269    182.944109     60.291332      7.670094
# min        1.000000      6.00000     21.000000      8.000000      0.000000
# 25%        4.000000     38.00000    149.000000     49.000000      8.000000
# 50%        6.000000     63.00000    250.000000     84.000000     12.000000
# 75%        8.000000     92.00000    380.000000    125.000000     17.000000
# max       50.000000    464.00000   2050.000000    643.000000    120.000000
#
#        avg.sentc.length  avg.word.length  avg.syll.word  sntc.per.word  \
# count      21848.000000     21848.000000   21848.000000   21848.000000
# mean          13.809381         4.067357       1.342886       0.102483
# std           11.050155         0.499582       0.146845       0.061841
# min            1.437500         2.230769       1.000000       0.005814
# 25%            8.000000         3.739726       1.242857       0.064516
# 50%           11.000000         4.027588       1.333333       0.090909
# 75%           15.500000         4.342857       1.427083       0.125000
# max          172.000000         9.913043       3.173913       0.695652
#
#                 TTR           ARI       Bormuth    Coleman.C1    Coleman.C2  \
# count  21848.000000  21848.000000  21848.000000  21848.000000  21848.000000
# mean       0.723674      4.631879     43.370350     59.889555     65.645048
# std        0.101544      6.329683     21.911381     10.534010     14.724470
# min        0.294118     -6.870000  -1157.490000    -17.000000      4.000000
# 25%        0.652778      1.090000     38.700000     54.000000     57.000000
# 50%        0.714286      3.460000     44.370000     60.000000     64.000000
# 75%        0.791667      6.480000     49.830000     67.000000     72.000000
# max        0.976190     89.460000     68.230000     91.000000    176.000000
#
#          Coleman.C3    Coleman.C4  Coleman.Liau    Dale.Chall  \
# count  21848.000000  21848.000000  21848.000000  21848.000000
# mean      68.684456     67.665644     65.624268     29.745908
# std       15.341690     14.380092     13.613754     12.818449
# min        3.000000      3.000000    -66.000000    -93.340000
# 25%       59.000000     59.000000     57.000000     24.450000
# 50%       68.000000     67.000000     65.000000     31.575000
# 75%       77.000000     75.000000     73.000000     38.092500
# max      154.000000    150.000000    143.000000     62.340000
#
#        Danielson.Bryan.DB1  Danielson.Bryan.DB2  Dickes.Steiwer  \
# count         21848.000000         21848.000000    21848.000000
# mean              6.722091            57.779240       49.764647
# std               1.425033            14.249944       11.459818
# min               4.330000          -153.590000      -24.170000
# 25%               5.910000            54.120000       43.000000
# 50%               6.390000            61.070000       50.575000
# 75%               7.090000            65.940000       57.650000
# max              27.860000            81.670000       88.940000
#
#                  DRP           ELF  Farr.Jenkins.Paterson        Flesch  \
# count   21848.000000  21848.000000           21848.000000  21848.000000
# mean    -4237.032398      3.411487              76.360335     79.210590
# std      2191.135801      3.333002              18.395556     18.083237
# min     -6723.320000      0.000000            -116.850000   -118.750000
# 25%     -4883.370000      1.670000              67.400000     70.757500
# 50%     -4336.940000      2.600000              77.880000     81.425000
# 75%     -3769.720000      4.000000              87.580000     90.627500
# max    115849.120000     76.000000             125.630000    119.480000
#
#        Flesch.Kincaid           FOG       FORCAST         Fucks  \
# count    21848.000000  21848.000000  21848.000000  21848.000000
# mean         5.641789      8.114505      8.565328     57.017064
# std          4.907920      5.079006      1.225581     48.890215
# min         -2.730000      0.580000      5.000000      4.940000
# 25%          2.900000      5.100000      7.780000     32.000000
# 50%          4.700000      7.200000      8.520000     44.800000
# 75%          7.100000      9.830000      9.290000     64.500000
# max         72.550000     76.240000     17.500000    909.000000
#
#        Linsear.Write           LIX          nWS1          nWS2          nWS3  \
# count   21848.000000  21848.000000  21848.000000  21848.000000  21848.000000
# mean        7.287823     29.780758      2.556273      3.337656      3.880060
# std         7.014159     14.022585      2.952831      2.860171      2.816081
# min        -0.280000      1.830000     -3.690000     -2.470000     -0.840000
# 25%         3.600000     21.400000      0.630000      1.490000      2.080000
# 50%         5.420000     27.495000      2.160000      2.930000      3.460000
# 75%         8.210000     35.000000      4.000000      4.690000      5.090000
# max       123.000000    202.810000     34.220000     34.700000     38.030000
#
#                nWS4           RIX          SMOG        Spache        Strain  \
# count  21848.000000  21848.000000  21848.000000  21848.000000  21848.000000
# mean       4.163852      2.332005      8.471857      4.715920      5.645222
# std        3.463302      2.523816      3.153475      1.575352      4.801180
# min       -1.310000      0.000000      3.130000      1.590000      0.450000
# 25%        2.130000      1.000000      6.630000      3.790000      3.180000
# 50%        3.620000      1.670000      8.240000      4.370000      4.450000
# 75%        5.380000      2.750000     10.130000      5.140000      6.402500
# max       49.890000     53.000000     37.880000     24.570000     92.100000
#
#        Traenkle.Bailer.TB1  Traenkle.Bailer.TB2           TRI       Tuldava  \
# count         21848.000000         21848.000000  21848.000000  21848.000000
# mean             53.268075            56.679412    -24.052349      3.292764
# std              13.470656            13.461499     13.251808      0.927456
# min             -21.070000           -21.970000   -294.750000      0.380000
# 25%              44.380000            47.670000    -30.100000      2.710000
# 50%              53.140000            56.320000    -22.250000      3.210000
# 75%              61.720000            65.030000    -15.750000      3.800000
# max             101.610000           118.390000     35.920000     10.490000
#
#        Wheeler.Smith          text          CTTR  HD-D (vocd-D)    Herdan's C  \
# count   21848.000000  21848.000000  21848.000000   21848.000000  21848.000000
# mean       34.114839   6216.995469      3.977075      29.984360      0.919822
# std        33.329948   4571.302323      0.926193       6.042278      0.029852
# min         0.000000      1.000000      1.250000       5.000000      0.720000
# 25%        16.670000   2390.000000      3.270000      27.407500      0.900000
# 50%        26.000000   5429.500000      3.920000      32.000000      0.920000
# 75%        40.000000   9270.250000      4.640000      34.230000      0.940000
# max       760.000000  17605.000000      8.440000      41.000000      0.990000
#
#              Maas a     Maas lgV0          MTLD      Root TTR        Summer  \
# count  21848.000000  21848.000000  21848.000000  21848.000000  21848.000000
# mean       0.209451      4.362450     60.711494      5.624327      0.839160
# std        0.038674      0.983674     30.001360      1.309898      0.097264
# min        0.060000      1.100000      5.360000      1.770000     -2.510000
# 25%        0.190000      3.730000     39.837500      4.620000      0.810000
# 50%        0.210000      4.320000     55.230000      5.540000      0.860000
# 75%        0.230000      4.840000     75.522500      6.570000      0.890000
# max        0.500000     14.230000    493.920000     11.930000      3.510000
#
#               TTR.1    Uber index      Yule's K
# count  21848.000000  21848.000000  21848.000000
# mean       0.723631     25.738000    175.051572
# std        0.101554     13.398543     96.376270
# min        0.290000      4.000000     11.340000
# 25%        0.650000     18.770000    110.190000
# 50%        0.710000     23.030000    151.910000
# 75%        0.790000     28.582500    214.160000
# max        0.980000    251.780000   1564.100000

# %%
y_train.describe()
# Out:
# count     21848
# unique        6
# top          A1
# freq       9089
# Name: level1, dtype: object

# %% [markdown]
# # Problème de régression ou de classification?

# %% [markdown]
# ## Si classification

# %%
y_train = y_train.replace({"A1": 0, "A2" : 1, "B1" : 2, "B2" : 3, "C1" : 4, "C2" : 5})
print(y_train)
print(y_train)
print(y_train.shape)
# Out:
# 17424    0
# 18934    0
# 4305     2
# 13039    1
# 13124    1
# 975      3
# 15651    1
# 7858     2
# 16417    0
# 9218     1
# 5558     2
# 6960     2
# 26357    0
# 8452     1
# 17726    0
# 6621     2
# 13599    1
# 21122    0
# 22536    0
# 7917     2
# 10313    1
# 1400     3
# 12854    1
# 16046    0
# 15536    1
# 16577    0
# 22664    0
# 3501     2
# 22119    0
# 14467    1
#         ..
# 20948    0
# 23160    0
# 294      4
# 26546    0
# 26592    0
# 5921     2
# 10436    1
# 15126    1
# 26936    0
# 26751    0
# 23610    0
# 7174     2
# 26668    0
# 7282     2
# 12623    1
# 18890    0
# 14348    1
# 7897     2
# 19331    0
# 23062    0
# 8159     2
# 10461    1
# 22960    0
# 20251    0
# 8129     2
# 5929     2
# 15435    1
# 1280     3
# 25741    0
# 14168    1
# Name: level1, Length: 21848, dtype: int64
# 17424    0
# 18934    0
# 4305     2
# 13039    1
# 13124    1
# 975      3
# 15651    1
# 7858     2
# 16417    0
# 9218     1
# 5558     2
# 6960     2
# 26357    0
# 8452     1
# 17726    0
# 6621     2
# 13599    1
# 21122    0
# 22536    0
# 7917     2
# 10313    1
# 1400     3
# 12854    1
# 16046    0
# 15536    1
# 16577    0
# 22664    0
# 3501     2
# 22119    0
# 14467    1
#         ..
# 20948    0
# 23160    0
# 294      4
# 26546    0
# 26592    0
# 5921     2
# 10436    1
# 15126    1
# 26936    0
# 26751    0
# 23610    0
# 7174     2
# 26668    0
# 7282     2
# 12623    1
# 18890    0
# 14348    1
# 7897     2
# 19331    0
# 23062    0
# 8159     2
# 10461    1
# 22960    0
# 20251    0
# 8129     2
# 5929     2
# 15435    1
# 1280     3
# 25741    0
# 14168    1
# Name: level1, Length: 21848, dtype: int64
# (21848,)

# %% [markdown]
# ## Forêt aléatoire
# Entrainement avec seulement les variables quantitatives

# %%
X_train_quant = X_train.iloc[:,1:]
X_train_quant

# %%
from sklearn.ensemble import RandomForestClassifier

n_estimators = 100

# %%
rf = RandomForestClassifier(n_estimators=n_estimators, n_jobs=-1)

# %% [markdown]
# ## Variables importantes

# %%
feature_importances = pd.DataFrame(rf.fit(X_train_quant, y_train).feature_importances_.reshape(1,-1), columns=list(X_train_quant))

# %%
feature_importances.sort_values(by=[0], axis=1, ascending=False, inplace=False, kind='quicksort', na_position='last')

# %% [markdown]
# Qu'est ce que la variable text?

# %% [markdown]
# # Mesure de l'erreur

# %%
from sklearn.metrics import confusion_matrix

# %%
costs = np.array([[0,1,2,3,4,6],[1,0,1,4,5,8],[3,2,0,3,5,8],[10,7,5,0,2,7],[20,16,12,4,0,8],[44,38,32,19,13,0]])
names = ['A1', 'A2', 'B1', 'B2', 'C1', 'C2']

# %%
def cost(estimator, X, y_true):
    y_pred = estimator.predict(X)
    confusion = confusion_matrix(y_true, y_pred)
    res = (1/y_true.shape[0]) * np.sum(np.multiply(costs, confusion))
    
    if print_confusion:
        confusion = pd.DataFrame(confusion, index = names, columns = names)
        print(confusion)
        print()
    return res

# %%
from sklearn.model_selection import cross_val_score

# %%
print_confusion = True
cross_val_score(rf, X_train_quant, y_train, scoring=cost, cv=5, n_jobs=-1, verbose=1)

# %% [markdown]
# # Un premier réseau de neurones

# %% [markdown]
# Représentation des données:
#
# Word2Vec:
# - http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
# - https://www.tensorflow.org/hub/modules/text
# - https://www.tensorflow.org/hub/modules/google/Wiki-words-250/1
# - http://mccormickml.com/2016/04/12/googles-pretrained-word2vec-model-in-python/
#
# ELMO ???:
# - peut être http://allennlp.org/elmo

# %% [markdown]
# Télécharger GoogleNews-vectors-negative300.bin à https://drive.google.com/file/d/0B7XkCwpI5KDYNlNUTTlSS21pQmM/edit?usp=sharing
# https://radimrehurek.com/gensim/models/word2vec.html

# %% [markdown]
# Quelques exemples avec Word2Vec

# %%
from gensim.models import KeyedVectors
word_vectors = KeyedVectors.load_word2vec_format('./GoogleNews-vectors-negative300.bin', binary=True)

# %%
vectors = word_vectors.wv['I love deep learning'.split()]
print(vectors.shape)
del vectors
# Out:
# (4, 300)
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.

# %%
vector = word_vectors.wv['university']
word_vectors.similar_by_vector(vector)
del vector
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.

# %%
import nltk

# %%
X_train_fulltext = X_train.loc[:, 'fulltext']
del X_train
X_train_fulltext.shape
# Out:
# (21848,)

# %% [markdown]
# On transforme chaque texte en une matrice avec des mots sous forme de vecteurs de taille 300.
#
# ATTENTION certains peuvent être vides après transformation

# %%
texts_matrices = []
total_nb_tokens = 0
total_nb_unknown = 0
avg_nb_unknown = 0
for row in X_train_fulltext:
    #print("===TEXT===")
    #print(row)
    tokens = nltk.word_tokenize(row)
    text_matrix = []
    nb_unknown = 0
    for word in tokens:
        try:
            word_emb = word_vectors.wv[word]
            text_matrix.append(word_emb)
            #print("Known word:", word)
        except:
            nb_unknown = nb_unknown+1
            #print("Unknown word:", word)
    if len(text_matrix)==0:
        text_matrix = np.zeros(texts_matrices[0].shape[1]).reshape(1,-1)
    texts_matrices.append(np.array(text_matrix))
    
    total_nb_tokens = total_nb_tokens + len(tokens)
    total_nb_unknown = total_nb_unknown + nb_unknown

texts_matrices = np.array(texts_matrices)
avg_nb_unknown = total_nb_unknown / total_nb_tokens
print("texts_matrices.shape=", texts_matrices.shape)
print("avg_nb_unknown=", avg_nb_unknown)
del word_vectors
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   del sys.path[0]
# texts_matrices.shape= (21848,)
# avg_nb_unknown= 0.24349061855180945

# %% [markdown]
# On complète chaque matrice par des vecteurs nuls pour avoir des matrices qui ont toutes la même taille.
# On commence par chercher la matrice la plus grande puis on complète les autres.

# %%
nb_words_max = -np.inf
for i in range(texts_matrices.shape[0]):
    nb_words = texts_matrices[i].shape[0]
    if nb_words > nb_words_max:
        nb_words_max = nb_words
print("Nombre de lignes de la plus grande matrice=", nb_words_max)
# Out:
# Nombre de lignes de la plus grande matrice= 418

# %% [markdown]
# On complète les matrices

# %%
import scipy

size_texts = np.zeros(texts_matrices.shape[0])
new_line = np.zeros((1, texts_matrices[1].shape[1]))

for i in range(texts_matrices.shape[0]):
    if i%100==0:
        print("i=", i)
    size_texts[i] = texts_matrices[i].shape[0]
    #print("i=", i)
    #print("texts_matrices[i].shape[0]=", texts_matrices[i].shape[0])
    #print("nb_words_max=", nb_words_max)
    while texts_matrices[i].shape[0] < nb_words_max:
        texts_matrices[i] = np.append(texts_matrices[i], new_line, axis=0)
    texts_matrices[i] = scipy.sparse.csr_matrix(texts_matrices[i])
#np.sort(size_texts)[-100:]
# Out:
# i= 0
# i= 100
# i= 200
# i= 300
# i= 400
# i= 500
# i= 600
# i= 700
# i= 800
# i= 900
# i= 1000
# i= 1100
# i= 1200
# i= 1300
# i= 1400
# i= 1500
# i= 1600
# i= 1700
# i= 1800
# i= 1900
# i= 2000
# i= 2100
# i= 2200
# i= 2300
# i= 2400
# i= 2500
# i= 2600
# i= 2700
# i= 2800
# i= 2900
# i= 3000
# i= 3100
# i= 3200
# i= 3300
# i= 3400
# i= 3500
# i= 3600
# i= 3700
# i= 3800
# i= 3900
# i= 4000
# i= 4100
# i= 4200
# i= 4300
# i= 4400
# i= 4500
# i= 4600
# i= 4700
# i= 4800
# i= 4900
# i= 5000
# i= 5100
# i= 5200
# i= 5300
# i= 5400
# i= 5500
# i= 5600
# i= 5700
# i= 5800
# i= 5900
# i= 6000
# i= 6100
# i= 6200
# i= 6300
# i= 6400
# i= 6500
# i= 6600
# i= 6700
# i= 6800
# i= 6900
# i= 7000
# i= 7100
# i= 7200
# i= 7300
# i= 7400
# i= 7500
# i= 7600
# i= 7700
# i= 7800
# i= 7900
# i= 8000
# i= 8100
# i= 8200
# i= 8300
# i= 8400
# i= 8500
# i= 8600
# i= 8700
# i= 8800
# i= 8900
# i= 9000
# i= 9100
# i= 9200
# i= 9300
# i= 9400
# i= 9500
# i= 9600
# i= 9700
# i= 9800
# i= 9900
# i= 10000
# i= 10100
# i= 10200
# i= 10300
# i= 10400
# i= 10500
# i= 10600
# i= 10700
# i= 10800
# i= 10900
# i= 11000
# i= 11100
# i= 11200
# i= 11300
# i= 11400
# i= 11500
# i= 11600
# i= 11700
# i= 11800
# i= 11900
# i= 12000
# i= 12100
# i= 12200
# i= 12300
# i= 12400
# i= 12500
# i= 12600
# i= 12700
# i= 12800
# i= 12900
# i= 13000
# i= 13100
# i= 13200
# i= 13300
# i= 13400
# i= 13500
# i= 13600
# i= 13700
# i= 13800
# i= 13900
# i= 14000
# i= 14100
# i= 14200
# i= 14300
# i= 14400
# i= 14500
# i= 14600
# i= 14700
# i= 14800
# i= 14900
# i= 15000
# i= 15100
# i= 15200
# i= 15300
# i= 15400
# i= 15500
# i= 15600
# i= 15700
# i= 15800
# i= 15900
# i= 16000
# i= 16100
# i= 16200
# i= 16300
# i= 16400
# i= 16500
# i= 16600
# i= 16700
# i= 16800
# i= 16900
# i= 17000
# i= 17100
# i= 17200
# i= 17300
# i= 17400
# i= 17500
# i= 17600
# i= 17700
# i= 17800
# i= 17900
# i= 18000
# i= 18100
# i= 18200
# i= 18300
# i= 18400
# i= 18500
# i= 18600
# i= 18700
# i= 18800
# i= 18900
# i= 19000
# i= 19100
# i= 19200
# i= 19300
# i= 19400
# i= 19500
# i= 19600
# i= 19700
# i= 19800
# i= 19900
# i= 20000
# i= 20100
# i= 20200
# i= 20300
# i= 20400
# i= 20500
# i= 20600
# i= 20700
# i= 20800
# i= 20900
# i= 21000
# i= 21100
# i= 21200
# i= 21300
# i= 21400
# i= 21500
# i= 21600
# i= 21700
# i= 21800

# %% [markdown]
# La suite ne marche pas ...

# %%
import sys
print(str(sys.getsizeof(texts_matrices)) + " octets")
file_name = "texts_matrices"
np.save(file_name, texts_matrices, allow_pickle=True, fix_imports=True)
scipy.sparse.save_npz(file_name, matrix=texts_matrices)
print(texts_matrices.shape)
print(texts_matrices[0].shape)
print(texts_matrices[1].shape)
print(size_texts)
y_train = np.array(y_train).reshape(-1,)
print(y_train.shape)
# Out:
# 174880 octets
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-a3d195cdb3a0> in <module>()
#       3 file_name = "texts_matrices"
#       4 #np.save(file_name, texts_matrices, allow_pickle=True, fix_imports=True)
# ----> 5 scipy.sparse.save_npz(file_name, matrix=texts_matrices)
#       6 print(texts_matrices.shape)
#       7 print(texts_matrices[0].shape)
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/sparse/_matrix_io.py in save_npz(file, matrix, compressed)
#      62     """
#      63
# ---> 64     arrays_dict = dict(format=matrix.format.encode('ascii'),
#      65                        shape=matrix.shape,
#      66                        data=matrix.data)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'format'

# %%
n_steps = texts_matrices[0].shape[0] #taille des textes (rendue fixe)
n_inputs = texts_matrices[0].shape[1] #taille des vecteurs représentant chaque mot
print("Nombre de mots des textes (fixe) =", n_steps)
print("Taille vecteur d'un mot =", n_inputs)
n_neurons = 500
n_outputs = 6

learning_rate = 0.001

n_epochs = 100
batch_size = 150
n_batches_per_epoch = texts_matrices.shape[0] // batch_size
print("Nombre de batchs par epoch =", n_batches_per_epoch)

# %%
import tensorflow as tf

tf.reset_default_graph()

X = tf.placeholder(tf.float32, shape=[None, n_steps, n_inputs], name="X")
seq_length = tf.placeholder(tf.int32, [None]) #nombre de mots dans le texte
y = tf.placeholder(tf.int64, shape=[None], name="y")

basic_cell = tf.contrib.rnn.BasicRNNCell(num_units=n_neurons)
outputs, states = tf.nn.dynamic_rnn(basic_cell, X, sequence_length=seq_length, dtype=tf.float32)

logits = tf.layers.dense(inputs=states, units=n_outputs, name="logits")
inference = tf.nn.softmax(logits, name="inference")

with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=y)
    loss = tf.reduce_mean(xentropy, name="loss")

with tf.name_scope("train"):
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    training_op = optimizer.minimize(loss)

with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

summary_writer = tf.summary.FileWriter("./summary", tf.get_default_graph())

init = tf.global_variables_initializer()
saver = tf.train.Saver()

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for iteration in range(n_batches_per_epoch):
            X_batch = texts_matrices[iteration*batch_size:(iteration+1)*batch_size] 
            #taille de X_batch (nb_texts=batch_size, nb_phrases (variable), taille d'un mot (300))
            print(X_batch.shape)
            print(X_batch.shape)
            y_batch = y_train[iteration*batch_size:(iteration+1)*batch_size]
            print(y_batch.shape)
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch, seq_length:1})
        acc_train = accuracy.eval(feed_dict={X: X_train, y: y_train})
        print(epoch, "Train accuracy:", acc_train)
    
    acc_test = accuracy.eval(feed_dict={X: X_test, y: y_test})
    print(epoch, "Test accuracy:", acc_test)

    save_path = saver.save(sess, "./natural_language_classifier.ckpt")
